# %%
# import packages
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from datetime import datetime


# !pip install folium
import folium

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

import math
import random
from datetime import timedelta

import warnings
warnings.filterwarnings('ignore')
import plotly as py
py.offline.init_notebook_mode(connected = True)
# Out:
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# read dataset
df = pd.read_csv('covid_case_type.csv')
casetype_all_states = df[['date', 'state', 'cases_new','cases_import']]
df2 = pd.read_csv('covid_case_age.csv')
caseage_all_states = df2[['state','cases_child','cases_adolescent','cases_adult','cases_elderly']]

# print casetype dataset
casetype_all_states
# Out:
#             date           state  cases_new  cases_import
# 0      25/1/2020        Malaysia          4             4
# 1      26/1/2020        Malaysia          0             0
# 2      27/1/2020        Malaysia          0             0
# 3      28/1/2020        Malaysia          0             0
# 4      29/1/2020        Malaysia          3             3
# ...          ...             ...        ...           ...
# 26906  21/5/2024  W.P. Putrajaya          3             0
# 26907  22/5/2024  W.P. Putrajaya          5             0
# 26908  23/5/2024  W.P. Putrajaya          6             0
# 26909  24/5/2024  W.P. Putrajaya          4             0
# 26910  25/5/2024  W.P. Putrajaya          5             0
#
# [26911 rows x 4 columns]

# %%
# print caseage dataset
caseage_all_states
# Out:
#                 state  cases_child  cases_adolescent  cases_adult  \
# 0            Malaysia            0                 0            1
# 1            Malaysia            0                 0            0
# 2            Malaysia            0                 0            0
# 3            Malaysia            0                 0            0
# 4            Malaysia            1                 0            2
# ...               ...          ...               ...          ...
# 26906  W.P. Putrajaya            0                 0            3
# 26907  W.P. Putrajaya            1                 0            4
# 26908  W.P. Putrajaya            0                 0            5
# 26909  W.P. Putrajaya            0                 1            3
# 26910  W.P. Putrajaya            1                 1            3
#
#        cases_elderly
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# ...

# %%
# list out all different states
casetype_all_states['state'].unique()
# Out:
# array(['Malaysia', 'Johor', 'Kedah', 'Kelantan', 'Melaka',
#        'Negeri Sembilan', 'Pahang', 'Perak', 'Perlis', 'Pulau Pinang',
#        'Sabah', 'Sarawak', 'Selangor', 'Terengganu', 'W.P. Kuala Lumpur',
#        'W.P. Labuan', 'W.P. Putrajaya'], dtype=object)

# %%
# list out all holidays in malaysia 2020
chinese_ny = ('25/1/2020', '26/1/2020')
labour_day = ('1/5/2020',)
wesak = ('7/5/2020',)
aidilfitri = ('24/5/2020', '25/5/2020')
ydpa_bday = ('8/6/2020',)
aidiladha = ('31/7/2020',)
maal_hijrah = ('20/8/2020',)
national_day = ('31/8/2020',)
malaysia_day = ('16/9/2020',)
maulidur_rasul = ('29/10/2020',)
deepavali = ('14/11/2020',)
christmas = ('25/12/2020',)

public_hol20 = (chinese_ny,labour_day,wesak,aidilfitri,ydpa_bday,aidiladha,maal_hijrah,national_day,malaysia_day,maulidur_rasul,deepavali,christmas)

# Flatten the list of holiday dates
public_hol20_flat = [date for sublist in public_hol20 for date in sublist]

# Convert the date column to datetime format
casetype_all_states['date'] = pd.to_datetime(casetype_all_states['date'], format='%d/%m/%Y')


# Convert public_hol20 dates to datetime format for comparison
public_hol20_dates = [datetime.strptime(date, '%d/%m/%Y') for date in public_hol20_flat]

# list out all holidays in malaysia 2021
chinese_ny = ('12/2/2021', '13/2/2021')
labour_day = ('1/5/2021',)
wesak = ('26/5/2021',)
aidilfitri = ('13/5/2021', '14/5/2021')
ydpa_bday = ('7/6/2021',)
aidiladha = ('20/7/2021',)
maal_hijrah = ('9/8/2021','10/8/2021')
national_day = ('31/8/2021',)
malaysia_day = ('16/9/2021',)
maulidur_rasul = ('19/10/2021',)
deepavali = ('4/11/2021',)
christmas = ('25/12/2021',)

public_hol21 = (chinese_ny,labour_day,wesak,aidilfitri,ydpa_bday,aidiladha,maal_hijrah,national_day,malaysia_day,maulidur_rasul,deepavali,christmas)

# Flatten the list of holiday dates
public_hol21_flat = [date for sublist in public_hol21 for date in sublist]

# Convert public_hol21 dates to datetime format for comparison
public_hol21_dates = [datetime.strptime(date, '%d/%m/%Y') for date in public_hol21_flat]

# list out all holidays in malaysia 2022
chinese_ny = ('1/2/2022', '2/2/2022')
labour_day = ('1/5/2022',)
wesak = ('16/5/2022',)
aidilfitri = ('1/5/2022', '2/5/2022')
ydpa_bday = ('6/6/2022',)
aidiladha = ('10/7/2022',)
maal_hijrah = ('30/7/2022',)
national_day = ('31/8/2022',)
malaysia_day = ('16/9/2022',)
maulidur_rasul = ('9/10/2022',)
deepavali = ('24/10/2022',)
christmas = ('26/12/2022',)

public_hol22 = (chinese_ny,labour_day,wesak,aidilfitri,ydpa_bday,aidiladha,maal_hijrah,national_day,malaysia_day,maulidur_rasul,deepavali,christmas)

# Flatten the list of holiday dates
public_hol22_flat = [date for sublist in public_hol22 for date in sublist]

# Convert public_hol22 dates to datetime format for comparison
public_hol22_dates = [datetime.strptime(date, '%d/%m/%Y') for date in public_hol22_flat]

# list out all holidays in malaysia 2023
chinese_ny = ('23/1/2023', '24/1/2023')
labour_day = ('1/5/2023',)
wesak = ('4/5/2023',)
aidilfitri = ('22/4/2023', '23/4/2023')
ydpa_bday = ('5/6/2023',)
aidiladha = ('29/6/2023',)
maal_hijrah = ('19/7/2023',)
national_day = ('31/8/2023',)
malaysia_day = ('16/9/2023',)
maulidur_rasul = ('28/9/2023',)
deepavali = ('13/11/2023',)
christmas = ('25/12/2023',)

public_hol23 = (chinese_ny,labour_day,wesak,aidilfitri,ydpa_bday,aidiladha,maal_hijrah,national_day,malaysia_day,maulidur_rasul,deepavali,christmas)

# Flatten the list of holiday dates
public_hol23_flat = [date for sublist in public_hol23 for date in sublist]


# Convert public_hol23 dates to datetime format for comparison
public_hol23_dates = [datetime.strptime(date, '%d/%m/%Y') for date in public_hol23_flat]

# list out all holidays in malaysia 2024
chinese_ny = ('10/2/2024','11/2/2024','12/2/2024')
labour_day = ('1/5/2024',)
wesak = ('22/5/2024',)
aidilfitri = ('10/4/2024', '11/4/2024')
ydpa_bday = ('3/6/2024',)
aidiladha = ('17/6/2024',)
maal_hijrah = ('7/7/2024',)
national_day = ('31/8/2024',)
malaysia_day = ('16/9/2024',)
maulidur_rasul = ('16/9/2024',)
deepavali = ('31/10/2024',)
christmas = ('25/12/2024',)

public_hol24 = (chinese_ny,labour_day,wesak,aidilfitri,ydpa_bday,aidiladha,maal_hijrah,national_day,malaysia_day,maulidur_rasul,deepavali,christmas)

# Flatten the list of holiday dates
public_hol24_flat = [date for sublist in public_hol24 for date in sublist]

# Convert public_hol24 dates to datetime format for comparison
public_hol24_dates = [datetime.strptime(date, '%d/%m/%Y') for date in public_hol24_flat]

# %%
# Function to get the start date of the epidemic for each year
def get_epidemic_start_date(year):
    if year == 2020:
        return datetime(year, 1, 25)
    else:
        return datetime(year, 1, 1)

# Function to convert date to epidemic week, restarting each year
def get_epidemic_week(date):
    epidemic_start_date = get_epidemic_start_date(date.year)
    if date < epidemic_start_date:
        return 1
    days_since_start = (date - epidemic_start_date).days
    epidemic_week = days_since_start // 7 + 1
    return epidemic_week

# Apply the function to the 'date' column to get the epidemic week
casetype_all_states['epidemic_week'] = casetype_all_states['date'].apply(get_epidemic_week)


casetype_all_states
# Out:
#             date           state  cases_new  cases_import  epidemic_week  \
# 0     2020-01-25        Malaysia          4             4              1
# 1     2020-01-26        Malaysia          0             0              1
# 2     2020-01-27        Malaysia          0             0              1
# 3     2020-01-28        Malaysia          0             0              1
# 4     2020-01-29        Malaysia          3             3              1
# ...          ...             ...        ...           ...            ...
# 26906 2024-05-21  W.P. Putrajaya          3             0             21
# 26907 2024-05-22  W.P. Putrajaya          5             0             21
# 26908 2024-05-23  W.P. Putrajaya          6             0             21
# 26909 2024-05-24  W.P. Putrajaya          4             0             21
# 26910 2024-05-25  W.P. Putrajaya          5             0             21
#
#       public_holiday mco monsoon_season
# 0                yes  no      Northeast
# ...

# %%
def public_holiday(dates):
    if dates in public_hol20_dates:
        return 'yes'
    if dates in public_hol21_dates:
        return 'yes'
    if dates in public_hol22_dates:
        return 'yes'
    if dates in public_hol23_dates:
        return 'yes'
    if dates in public_hol24_dates:
        return 'yes'
    return 'no'

casetype_all_states['public_holiday'] = casetype_all_states['date'].apply(public_holiday)

#casetype_all_states['date'] = casetype_all_states['date'].dt.strftime('%d/%m/%Y')
casetype_all_states
# Out:
#             date           state  cases_new  cases_import  epidemic_week  \
# 0     2020-01-25        Malaysia          4             4              1
# 1     2020-01-26        Malaysia          0             0              1
# 2     2020-01-27        Malaysia          0             0              1
# 3     2020-01-28        Malaysia          0             0              1
# 4     2020-01-29        Malaysia          3             3              1
# ...          ...             ...        ...           ...            ...
# 26906 2024-05-21  W.P. Putrajaya          3             0             17
# 26907 2024-05-22  W.P. Putrajaya          5             0             17
# 26908 2024-05-23  W.P. Putrajaya          6             0             18
# 26909 2024-05-24  W.P. Putrajaya          4             0             18
# 26910 2024-05-25  W.P. Putrajaya          5             0             18
#
#       public_holiday
# 0                yes
# 1                yes
# 2                 no
# ...

# %%
start_mco = datetime.strptime('2020-03-18', '%Y-%m-%d')
end_mco = datetime.strptime('2022-01-03', '%Y-%m-%d')

def dates_of_mco(dates):
    if (dates>=start_mco and dates<=end_mco):
        return 'yes'
    return 'no'

casetype_all_states['mco'] = casetype_all_states['date'].apply(dates_of_mco)
casetype_all_states
# Out:
#             date           state  cases_new  cases_import  epidemic_week  \
# 0     2020-01-25        Malaysia          4             4              1
# 1     2020-01-26        Malaysia          0             0              1
# 2     2020-01-27        Malaysia          0             0              1
# 3     2020-01-28        Malaysia          0             0              1
# 4     2020-01-29        Malaysia          3             3              1
# ...          ...             ...        ...           ...            ...
# 26906 2024-05-21  W.P. Putrajaya          3             0             17
# 26907 2024-05-22  W.P. Putrajaya          5             0             17
# 26908 2024-05-23  W.P. Putrajaya          6             0             18
# 26909 2024-05-24  W.P. Putrajaya          4             0             18
# 26910 2024-05-25  W.P. Putrajaya          5             0             18
#
#       public_holiday mco
# 0                yes  no
# 1                yes  no
# ...

# %%
# Function to determine the monsoon season
def monsoon_season(date):
    month = date.month
    if month in [11, 12, 1, 2, 3]:
        return 'Northeast'
    elif month in [5, 6, 7, 8, 9]:
        return 'Southwest'
    else:
        return 'Inter-Monsoon'

# Create a new column 'Monsoon Season' based on the monsoon season
casetype_all_states['monsoon_season'] = casetype_all_states['date'].apply(monsoon_season)
casetype_all_states
# Out:
#             date           state  cases_new  cases_import  epidemic_week  \
# 0     2020-01-25        Malaysia          4             4              1
# 1     2020-01-26        Malaysia          0             0              1
# 2     2020-01-27        Malaysia          0             0              1
# 3     2020-01-28        Malaysia          0             0              1
# 4     2020-01-29        Malaysia          3             3              1
# ...          ...             ...        ...           ...            ...
# 26906 2024-05-21  W.P. Putrajaya          3             0             17
# 26907 2024-05-22  W.P. Putrajaya          5             0             17
# 26908 2024-05-23  W.P. Putrajaya          6             0             18
# 26909 2024-05-24  W.P. Putrajaya          4             0             18
# 26910 2024-05-25  W.P. Putrajaya          5             0             18
#
#       public_holiday mco monsoon_season
# 0                yes  no      Northeast
# ...

# %%
# define a variable just for Malaysia
casetype_malaysia = casetype_all_states.query('state == "Malaysia"')
casetype_malaysia
# Out:
#            date     state  cases_new  cases_import  epidemic_week  \
# 0    2020-01-25  Malaysia          4             4              1
# 1    2020-01-26  Malaysia          0             0              1
# 2    2020-01-27  Malaysia          0             0              1
# 3    2020-01-28  Malaysia          0             0              1
# 4    2020-01-29  Malaysia          3             3              1
# ...         ...       ...        ...           ...            ...
# 1578 2024-05-21  Malaysia        237             3             17
# 1579 2024-05-22  Malaysia        195             0             17
# 1580 2024-05-23  Malaysia        222             0             18
# 1581 2024-05-24  Malaysia        247             1             18
# 1582 2024-05-25  Malaysia        222             0             18
#
#      public_holiday mco monsoon_season
# 0               yes  no      Northeast
# 1               yes  no      Northeast
# 2                no  no      Northeast
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = casetype_malaysia['date'], y = casetype_malaysia['cases_new'], name = 'New Cases', mode='markers'))
fig.add_trace(go.Scatter(x = casetype_malaysia['date'], y = casetype_malaysia['cases_import'], name = 'Imported Cases', mode='markers'))
fig.update_layout(title = 'COVID-19 Cases in Malaysia by Type of Cases', xaxis_tickfont_size = 14, yaxis = dict(title = 'Number of Cases'))
fig.show()
# Out:
# <div>                            <div id="90643ea6-6e37-4e20-b9d1-0cf9e8260afc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90643ea6-6e37-4e20-b9d1-0cf9e8260afc")) {                    Plotly.newPlot(                        "90643ea6-6e37-4e20-b9d1-0cf9e8260afc",                        [{"mode":"markers","name":"New Cases","x":["2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-0
# ...

# %%
malaysia_holiday = casetype_malaysia.query('public_holiday == "yes"')
malaysia_xholiday = casetype_malaysia.query('public_holiday == "no"')
malaysia_holiday
# Out:
#            date     state  cases_new  cases_import  epidemic_week  \
# 0    2020-01-25  Malaysia          4             4              1
# 1    2020-01-26  Malaysia          0             0              1
# 97   2020-05-01  Malaysia         69            12             14
# 103  2020-05-07  Malaysia         39             1             15
# 120  2020-05-24  Malaysia         60             7             18
# ...         ...       ...        ...           ...            ...
# 1479 2024-02-12  Malaysia         63             1              3
# 1537 2024-04-10  Malaysia         40             0             11
# 1538 2024-04-11  Malaysia         31             0             12
# 1558 2024-05-01  Malaysia        115             1             14
# 1579 2024-05-22  Malaysia        195             0             17
#
#      public_holiday  mco monsoon_season
# 0               yes   no      Northeast
# 1               yes   no      Northeast
# 97              yes  yes      Southwest
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = malaysia_holiday['date'], y = malaysia_holiday['cases_new'], mode='markers', name = 'Public Holiday', line = dict(color = "Purple", width = 5)))
fig.add_trace(go.Scatter(x = malaysia_xholiday['date'], y = malaysia_xholiday['cases_new'], mode='lines', name = 'Daily New Cases', line = dict(color = "Orange", width = 1)))
fig.update_layout(title = 'COVID-19 Cases in Malaysia by Holidays', xaxis_tickfont_size = 14, yaxis = dict(title = 'Number of Cases'))
fig.show()
# Out:
# <div>                            <div id="a1cf7484-b263-49d3-bfde-c64bc7c0e4d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1cf7484-b263-49d3-bfde-c64bc7c0e4d5")) {                    Plotly.newPlot(                        "a1cf7484-b263-49d3-bfde-c64bc7c0e4d5",                        [{"line":{"color":"Purple","width":5},"mode":"markers","name":"Public Holiday","x":["2020-01-25T00:00:00","2020-01-26T00:00:00","2020-05-01T00:00:00","2020-05-07T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-06-08T00:00:00","2020-07-31T00:00:00","2020-08-20T00:00:00","2020-08-31T00:00:00","2020-09-16T00:00:00","2020-10-29T00:00:00","2020-11-14T00:00:00","2020-12-25T00:00:00","2021-02-12T00:00:00","2021-02-13T00:00:00","2021-05-01T00:00:00","2021-05-1
# ...

# %%
malaysia_ne_monsoon = casetype_malaysia.query('monsoon_season == "Northeast"')
malaysia_sw_monsoon = casetype_malaysia.query('monsoon_season == "Southwest"')
malaysia_in_monsoon = casetype_malaysia.query('monsoon_season == "Inter-Monsoon"')

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = malaysia_ne_monsoon['date'], y = malaysia_ne_monsoon['cases_new'], mode='markers', name = 'Northeast Monsoon', line = dict(color = "Purple", width = 1)))
fig.add_trace(go.Scatter(x = malaysia_sw_monsoon['date'], y = malaysia_sw_monsoon['cases_new'], mode='markers', name = 'Southwest Monsoon', line = dict(color = "Orange", width = 1)))
fig.add_trace(go.Scatter(x = malaysia_in_monsoon['date'], y = malaysia_in_monsoon['cases_new'], mode='markers', name = 'Inter-Monsoon', line = dict(color = "Blue", width = 1)))
fig.update_layout(title = 'COVID-19 Cases in Malaysia by Monsoon Season', xaxis_tickfont_size = 14, yaxis = dict(title = 'Number of Cases'))
fig.show()
# Out:
# <div>                            <div id="44f9b229-c271-4a2b-a4fd-5e849e6db5c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44f9b229-c271-4a2b-a4fd-5e849e6db5c8")) {                    Plotly.newPlot(                        "44f9b229-c271-4a2b-a4fd-5e849e6db5c8",                        [{"line":{"color":"Purple","width":1},"mode":"markers","name":"Northeast Monsoon","x":["2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-0
# ...

# %%
xmalaysia = casetype_all_states.query('state != "Malaysia"')
temp = xmalaysia.groupby('state')[['cases_new']].sum().reset_index()
temp.rename(columns = {'cases_new':'New Cases'}, inplace = True)
temp.rename(columns = {'state':'States'}, inplace = True)

# %%
fig = px.treemap(temp.sort_values(by = 'New Cases', ascending = False).reset_index(drop = True),
                 path = ['States'], values = 'New Cases', height = 700,
                 title = 'Sum Number of Cases by States',
                 color_discrete_sequence = px.colors.qualitative.Dark2)
fig.data[0].textinfo = 'label+text+value'
fig.show()
# Out:
# <div>                            <div id="df960ed9-a143-4f08-9870-423eda8feed1" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df960ed9-a143-4f08-9870-423eda8feed1")) {                    Plotly.newPlot(                        "df960ed9-a143-4f08-9870-423eda8feed1",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>New Cases=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Johor","Kedah","Kelantan","Melaka","Negeri Sembilan","Pahang","Perak","Perlis","Pulau Pinang","Sabah","Sarawak","Selangor","Terengganu","W.P. Kuala Lumpur","W.P. Labuan","W.P. Putrajaya"],"labels":["Johor","Kedah","Kelantan","Melaka","Negeri Sembilan","Pahang","Perak","Perlis","Pulau Pinang",
# ...

# %%
agegroup_malaysia = caseage_all_states.query('state == "Malaysia"')
agegroup_temp = agegroup_malaysia.groupby('state')[['cases_child','cases_adolescent','cases_adult','cases_elderly']].sum().reset_index()
agegroup_temp.rename(columns = {'cases_child':'Child'}, inplace = True)
agegroup_temp.rename(columns = {'cases_adolescent':'Adolescent'}, inplace = True)
agegroup_temp.rename(columns = {'cases_adult':'Adult'}, inplace = True)
agegroup_temp.rename(columns = {'cases_elderly':'Elderly'}, inplace = True)
age_grouping = agegroup_temp.melt(id_vars = 'state', value_vars = ['Child','Adolescent','Adult','Elderly'], var_name = "Age Groups", value_name ="Total")
age_grouping
# Out:
#       state  Age Groups    Total
# 0  Malaysia       Child   645693
# 1  Malaysia  Adolescent   328697
# 2  Malaysia       Adult  3723328
# 3  Malaysia     Elderly   502241

# %%
fig = px.pie(age_grouping, values='Total', names='Age Groups',
             title='Sum of New Cases by Age Group')
fig.update_traces(textposition='outside', textinfo='percent+value')
fig.show()
# Out:
# <div>                            <div id="fae42809-50f0-4181-a11b-c665d471fc5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fae42809-50f0-4181-a11b-c665d471fc5f")) {                    Plotly.newPlot(                        "fae42809-50f0-4181-a11b-c665d471fc5f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Age Groups=%{label}<br>Total=%{value}<extra></extra>","labels":["Child","Adolescent","Adult","Elderly"],"legendgroup":"","name":"","showlegend":true,"values":[645693,328697,3723328,502241],"type":"pie","textinfo":"percent+value","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.
# ...

# %%
malaysia_mco = casetype_malaysia.query('mco == "yes"')
malaysia_xmco = casetype_malaysia.query('mco == "no"')

fig = go.Figure()
fig.add_trace(go.Scatter(x = malaysia_mco['date'], y = malaysia_mco['cases_new'], mode='lines', name = 'MCO', line = dict(color = "Purple", width = 1)))
fig.add_trace(go.Scatter(x = malaysia_xmco['date'], y = malaysia_xmco['cases_new'], mode='markers', name = 'Non-MCO', line = dict(color = "Orange", width = 0.5)))

fig.update_layout(title = 'COVID-19 Cases in Malaysia by MCO', xaxis_tickfont_size = 14, yaxis = dict(title = 'Number of Cases'))
fig.show()
# Out:
# <div>                            <div id="2293cf97-2441-46a5-b50b-06e8400b4d2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2293cf97-2441-46a5-b50b-06e8400b4d2e")) {                    Plotly.newPlot(                        "2293cf97-2441-46a5-b50b-06e8400b4d2e",                        [{"line":{"color":"Purple","width":1},"mode":"lines","name":"MCO","x":["2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","
# ...
